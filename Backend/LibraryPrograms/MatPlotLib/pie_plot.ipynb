# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
y  = np.array([35,25,25,15])
plt.pie(y)
plt.show()

# %%
# ------------------------------------------------------------
#   football hockey   cricket   basketball    badminton
#   -----------------------------------------------------
#    10     5          5          10            10
# -------------------------------------------------------
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
a = np.array([10,5,5,10,10])
plt.pie(a)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a = np.array([10,5,5,10,10])
labs=["Football","Hockey","Cricket","Basketball","Badminton"]
plt.pie(a,labels=labs)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games = [10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,startangle=90)  # startangle = 90
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games=[10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,explode=[0.2,0,0,0,0])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games=[10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,explode=[0.05,0,0,0,0])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games=[10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,explode=[0.09,0,0,0,0],shadow=True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games=[10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,explode=[0.09,0,0,0,0],colors=["black","hotpink","b","red","yellow"])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games=[10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,explode=[0.09,0,0,0,0],colors=["black","hotpink","b","red","yellow"])
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
games=[10,5,5,10,10]
labs=["Football","Hockey","Cricket","Basketball","Badmintain"]
plt.pie(games,labels=labs,explode=[0.09,0,0,0,0],colors=["black","hotpink","b","red","yellow"])
plt.legend(title="Games")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.title("Games View",color="green",fontweight="bold",fontsize="20")
sport=[10,5,5,10,10]
spnames=["Football","Hockey","Cricket","Basketball","Badmintain"]
cols=["gold","green","hotpink","cyan","blue"]
plt.pie(sport,labels=spnames,explode=[0.1,0,0,0,0],colors=cols,startangle=90,autopct="%0.0f%%",
        wedgeprops={"linewidth":4,"edgecolor":"red"})
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.title("Games View",color="green",fontweight="bold",fontsize="20")
sport=[10,5,5,10,10]
spnames=["Football","Hockey","Cricket","Basketball","Badmintain"]
cols=["gold","green","hotpink","cyan","blue"]
plt.pie(sport,labels=spnames,explode=[0.1,0,0,0,0],colors=cols,autopct="%0.0f%%",
        wedgeprops={"linewidth":4,"edgecolor":"red"})
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.title("Games View",color="green",fontweight="bold",fontsize="20")
sport=[10,5,5,10,10]
spnames=["Football","Hockey","Cricket","Basketball","Badmintain"]
cols=["gold","green","hotpink","cyan","blue"]
plt.pie(sport,labels=spnames,explode=[0.1,0,0,0,0],colors=cols,autopct="%0.2f%%",
        wedgeprops={"linewidth":4,"edgecolor":"red"})
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.title("Games View",color="green",fontweight="bold",fontsize="20")
sport=[10,5,5,10,10]
spnames=["Football","Hockey","Cricket","Basketball","Badmintain"]
cols=["gold","green","hotpink","cyan","blue"]
plt.pie(sport,labels=spnames,explode=[0.1,0,0,0,0],colors=cols,startangle=90,autopct="%0.4f%%",
        wedgeprops={"linewidth":4,"edgecolor":"red"})
plt.show()

# %%
#============================================x==================================================
#Question: Priya lists down her monthly expenditure as follows:
#
#			Expenditure	Amount
#			Rent		4000
#			Food		5400
#			Clothing	2800
#			Savings		400
#		Draw a pie chart for her monthly expenses.

# %%
from matplotlib import pyplot as plt
plt.title("Expenditure",color="green",fontweight="bold",fontsize=20)
exprs=[4000,5400,2800,1400]
expnames=["Rent","Food","Clothing","Savings"]
cols=['rosybrown', 'moccasin', 'lightyellow', 'darkseagreen']
plt.pie(exprs,labels=expnames,explode=[0.1,0,0,0],colors=cols,autopct='%0.0f%%',
        wedgeprops={'linewidth':4,'edgecolor':"red"})
plt.show()
