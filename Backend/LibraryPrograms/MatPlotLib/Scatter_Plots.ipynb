# %%
import numpy as np
import matplotlib.pyplot as plt
#* Here we can take the value into the numpy array
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6]) # Age of Car
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86]) # Speed of the Car
plt.scatter(x,y)
plt.show()

#* there negative correlation in there

# %%
import matplotlib.pyplot as plt
import pandas as pd
d = {"CarAge" :[5,7,8,7,2,17,2,9,4,11,12,9,6],               # Age of Car
     "CarSpeed":[99,86,87,88,111,86,103,87,94,78,77,85,86]} # Speed of the Car
print(d,type(d))
# Out:
# {'CarAge': [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6], 'CarSpeed': [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]} <class 'dict'>

# %%
#* It by Default take the blue color to the Dot
import matplotlib.pyplot as plt
import pandas as pd
d = {"CarAge" :[5,7,8,7,2,17,2,9,4,11,12,9,6],               # Age of Car
     "CarSpeed":[99,86,87,88,111,86,103,87,94,78,77,85,86]} # Speed of the Car
#Convert Dict into DataFrame
df = pd.DataFrame(d)
print("----------------------------------")
print(df)
print("----------------------------------")
plt.scatter(df["CarAge"],df["CarSpeed"])
plt.show()
# Out:
# ----------------------------------
#     CarAge  CarSpeed
# 0        5        99
# 1        7        86
# 2        8        87
# 3        7        88
# 4        2       111
# 5       17        86
# 6        2       103
# 7        9        87
# 8        4        94
# 9       11        78
# 10      12        77
# 11       9        85
# 12       6        86
# ----------------------------------

# %%
#* change the color of default
import pandas as pd
import matplotlib .pyplot as plt
d = {"CarAge" :[5,7,8,7,2,17,2,9,4,11,12,9,6],               # Age of Car
     "CarSpeed":[99,86,87,88,111,86,103,87,94,78,77,85,86]} # Speed of the Car
#Convert Dict into DataFrame
print("---------------------")
print(df)
print("---------------------")
plt.scatter(df["CarAge"],df["CarSpeed"],c = "red")
plt.show()
# Out:
# ---------------------
#     CarAge  CarSpeed
# 0        5        99
# 1        7        86
# 2        8        87
# 3        7        88
# 4        2       111
# 5       17        86
# 6        2       103
# 7        9        87
# 8        4        94
# 9       11        78
# 10      12        77
# 11       9        85
# 12       6        86
# ---------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
d = {"CarAge" :[5,7,8,7,2,17,2,9,4,11,12,9,6],               # Age of Car
     "CarSpeed":[99,86,87,88,111,86,103,87,94,78,77,85,86]} # Speed of the Car
#Convert Dict into DataFrame
print("--------------------------")
print(df)
print("--------------------------")
plt.scatter(df["CarAge"],df["CarSpeed"],c= "red",s = 100)  #* s =100  size of the observation s 
plt.show()
# Out:
# --------------------------
#     CarAge  CarSpeed
# 0        5        99
# 1        7        86
# 2        8        87
# 3        7        88
# 4        2       111
# 5       17        86
# 6        2       103
# 7        9        87
# 8        4        94
# 9       11        78
# 10      12        77
# 11       9        85
# 12       6        86
# --------------------------

# %%
import pandas as pd
import matplotlib.pyplot  as plt
d = {"CarAge" :[5,7,8,7,2,17,2,9,4,11,12,9,6],               # Age of Car
     "CarSpeed":[99,86,87,88,111,86,103,87,94,78,77,85,86]} # Speed of the Car
#Convert Dict into DataFrame
print("--------------------------")
print(df)
print("--------------------------")
plt.scatter(df["CarAge"],df["CarSpeed"],c= "red",s = 100,marker="D")  #* s =100  size of the observation s 
plt.show()
# Out:
# --------------------------
#     CarAge  CarSpeed
# 0        5        99
# 1        7        86
# 2        8        87
# 3        7        88
# 4        2       111
# 5       17        86
# 6        2       103
# 7        9        87
# 8        4        94
# 9       11        78
# 10      12        77
# 11       9        85
# 12       6        86
# --------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# day one, the age and speed of the 13 cars
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
# plt.show()
# day two ,the age and speed of 15 cars
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)
plt.show()

# %%
#! Set the different color to the observations
#!  we can take multiple color 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors =["red","green","blue","yellow","pink","black","orange","purple",
        "beige","brown","gray","cyan","magenta"]
plt.scatter(x,y,c = colors,s=50)
plt.show()

# %%
#! ColorMap
#=>You can specify the colormap with the keyword argument cmap with the value of the colormap, 
# in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#=>In addition you have to create an array with values (from 0 to 100),
#  one value for each point in the scatter plot:
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]) #* we can must provide a proper value to it
plt.scatter(x, y, c=colors, cmap='viridis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y,c=colors,cmap="viridis")
plt.colorbar()    # here cmap values can be  "summer"  "rainbow" , "prism" , "spring" , "plasma" , "magma", "Blues"..etc
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y,c=colors,cmap="rainbow")
plt.colorbar()    # here cmap values can be  "summer"  "rainbow" , "prism" , "spring" , "plasma" , "magma", "Blues"..etc
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y,c=colors,cmap="viridis",s=sizes)
plt.show()

# %%
#! this is different from other 
#todo - WITHOUT the colorbar() function 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y,c = colors,cmap="rainbow",s=sizes)

plt.show()

# %%
#! this is different from other 
#todo - WITH  the colorbar() function 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y,c = colors,cmap="rainbow",s=sizes)
plt.colorbar()
plt.show()

# %%
#----------------------
#Problems
#-----------------------
#Let us understand how to construct a scatter plot with the help of the below example.
#Draw a scatter plot for the given data that shows the number of games played and
#  scores obtained in each instance.

#No. of games	3	5	2	6	7	1	2	7	1	7
#Scores		80	90	75	80	90	50	65	85	40	100

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
d = {"no_of_games":[3,5,2,6,7,1,2,7,1,7],
     "Scores":[80,90,75,80,90,50,65,85,40,100]}
df = pd.DataFrame(d)
print("----------------------------")
print(df)
print("----------------------------")
# Out:
# ----------------------------
#    no_of_games  Scores
# 0            3      80
# 1            5      90
# 2            2      75
# 3            6      80
# 4            7      90
# 5            1      50
# 6            2      65
# 7            7      85
# 8            1      40
# 9            7     100
# ----------------------------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
d = {"no_of_games":[3,5,2,6,7,1,2,7,1,7],
     "Scores":[80,90,75,80,90,50,65,85,40,100]}
df = pd.DataFrame(d)
print("----------------------------")
print(df)
print("----------------------------")
plt.scatter(df["no_of_games"],df["Scores"])
plt.show()
# Out:
# ----------------------------
#    no_of_games  Scores
# 0            3      80
# 1            5      90
# 2            2      75
# 3            6      80
# 4            7      90
# 5            1      50
# 6            2      65
# 7            7      85
# 8            1      40
# 9            7     100
# ----------------------------

# %%
#Problems
#-----------------------
#Every year, a meteorologist studying tropical storms predicts how many hurricanes will occur. 
#The table below shows how many hurricanes were predicted and how many hurricanes actually occurred for the years 
# 2000 to 2005

 
#Year:		2000	2001	2002       2003       2004    2005
#Predicted	11		13		12		    17		   15	   17-------------------x axis
#Actual		14		15		12	        16		   14	   27-------------------y-axis

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
d={"Predicted":[11,13,12,17,15,17],
    "Actual":[14,15,12,16,14,27]}
# print(d)
df = pd.DataFrame(d)
print("-----------------------------")
print(df)
print("-----------------------------")
plt.scatter(df["Predicted"],df["Actual"])
plt.show()  #* it is the Positive Correlation
# Out:
# -----------------------------
#    Predicted  Actual
# 0         11      14
# 1         13      15
# 2         12      12
# 3         17      16
# 4         15      14
# 5         17      27
# -----------------------------

# %%
#Problem
#------------
#Rossum is curious how different amounts of sunlight will impact the growth of his tomatoes. 
#he exposed some of his tomatoes to varying amounts of sunlight (in hours per day) and recorded the change 
#in their circumferences (in centimeters) after a week. His data is summarized in the table below.
#		Sunlight (hours per day)	: 0     2    4       6      8
  
#     Change in circumference (cm)	:1.00  2.50 5.25  10.75   11.25
#!   DOing this problem with Series 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
Sunlight = pd.Series([0,2,4,6 ,8])
circumference = pd.Series([1.00,2.50,5.25,10.75,11.25])
print(Sunlight)    # Series of Values 
print(circumference)  # Series of Values
# Out:
# 0    0
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64
# 0     1.00
# 1     2.50
# 2     5.25
# 3    10.75
# 4    11.25
# dtype: float64

# %%
#!   DOing this problem with Series 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
Sunlight = pd.Series([0,2,4,6 ,8])
circumference = pd.Series([1.00,2.50,5.25,10.75,11.25])
print(Sunlight)    # Series of Values 
print(circumference)  # Series of Values 
print("------------------------")
plt.scatter(Sunlight,circumference)
plt.show()
# positive Correlation here
# Out:
# 0    0
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64
# 0     1.00
# 1     2.50
# 2     5.25
# 3    10.75
# 4    11.25
# dtype: float64
# ------------------------
