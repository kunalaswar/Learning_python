# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement =[150,175,125,100]
plt.bar(year,placement)
plt.show()

# %%
#! stacked bar graph
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement =[150,175,125,100]
plt.bar(year,placement)
plt.show()

# %%
#! horizontal stacked bar graph

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse =[80,95,65,50]
it =[30,25,20,15]
plt.bar(year,cse,color = "red")
plt.bar(year,it,bottom=cse,color="green")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse =[80,95,65,50]
it =[30,25,20,15]
ece=[12,15,6,18]
ece_start = [cse[i]+it[0] for i in range(len(year))]
print(ece_start) #todo  -Adding the two list into single list
#*   [110, 125, 95, 80] it is the height of two bar and we placed the New bar into it
# Out:
# [110, 125, 95, 80]

# %%
#! By default color it taking in this 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse =[80,95,65,50]
it =[30,25,20,15]
ece=[12,15,6,18]
ece_start = [cse[i]+ it[i] for i in range(len(year))]
plt.bar(year,cse)
plt.bar(year,it,bottom=cse)
plt.bar(year,ece,bottom=ece_start)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse =[80,95,65,50]
it =[30,25,20,15]
ece=[12,15,6,18]
ece_start =[cse[i]+it[i] for i in range(len(year))]
# print(ece_start)
plt.bar(year,cse,color="red")
plt.bar(year,it,bottom=cse,color="orange")
plt.bar(year,ece,bottom=ece_start,color="purple")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i]+it[i] for i in range(len(year))]
eee_start = [cse[i] +it[i] +ece[i]  for i in range(len(year))]
plt.bar(year,cse,color="red")
plt.bar(year,it,bottom=cse,color="orange")
plt.bar(year,ece,bottom=ece_start,color="purple")
plt.bar(year,eee,bottom=eee_start)
plt.show()

# %%
#! Without Given a color
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] + it[i] for i in range(len(year))]
eee_start = [cse[i] + it[i] + ece[i] for i in range(len(year))]

print(ece_start)
print("------------------------------")
print(eee_start)
# Out:
# [110, 120, 85, 65]
# ------------------------------
# [122, 135, 91, 83]

# %%
#! Without Given a color
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] + it[i] for i in range(len(year))]
eee_start = [cse[i] + it[i] + ece[i] for i in range(len(year))]

plt.bar(year,cse)
plt.bar(year,it,bottom=cse)
plt.bar(year,ece,bottom=ece_start)  
plt.bar(year,eee,bottom=eee_start) 
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] + it[i] for i  in range(len(year))]
eee_start = [cse[i] + it[i] + ece[i] for i in range(len(year))]
plt.bar(year,cse,color="green")
plt.bar(year,it,bottom=cse,color="red")
plt.bar(year,ece,bottom=ece_start,color="orange")
plt.bar(year,eee,bottom=eee_start,color="purple")
plt.show()

# %%
#! Another way of list compression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] +it[i] for i in range(len(year))]
eee_start = [ece_start[i] + ece[i] for i in range(len(year))]   #todo - this type also we can written  
# print(ece_start)
# print(eee_start)
plt.bar(year,cse,color="green")
plt.bar(year,it,bottom=cse,color="red")
plt.bar(year,ece,bottom=ece_start,color="orange")
plt.bar(year,eee,bottom=eee_start,color="purple")
plt.show()

# %%
#! Add the legends
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] +it[i] for i in range(len(year))]
eee_start = [ece_start[i] + ece[i] for i in range(len(year))]   #todo - this type also we can written  
# print(ece_start)
# print(eee_start)
plt.bar(year,cse,color="green",label="CSE")
plt.bar(year,it,bottom=cse,color="red",label="IT")
plt.bar(year,ece,bottom=ece_start,color="orange",label="ECE")
plt.bar(year,eee,bottom=eee_start,color="purple",label="EEE")
plt.legend()
plt.show()

# %%
#! Horizontal bar graph
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
plt.barh(year,placement)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
plt.barh(year,cse,color="red")
plt.barh(year,it,left=cse,color="green")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
ece_start = [cse[i] + it[i] for i in range(len(year))]
plt.barh(year,cse,color="red")
plt.barh(year,it,left=cse,color="green")
plt.barh(year,ece,left=ece_start)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse =[80,95,65,50]
it =[30,25,20,15]
ece=[12,15,6,18]
ece_start =[cse[i]+it[i] for i in range(len(year))]
# print(ece_start)
plt.barh(year,cse,color="red")
plt.barh(year,it,left=cse,color="orange")
plt.barh(year,ece,left=ece_start,color="purple")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] + it[i] for i  in range(len(year))]
eee_start = [cse[i] + it[i] + ece[i] for i in range(len(year))]
plt.barh(year,cse,color="green")
plt.barh(year,it,left=cse,color="red")
plt.barh(year,ece,left=ece_start,color="orange")
plt.barh(year,eee,left=eee_start,color="purple")
plt.show()

# %%
#! Another way of list compression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] +it[i] for i in range(len(year))]
eee_start = [ece_start[i] + ece[i] for i in range(len(year))]   #todo - this type also we can written  
# print(ece_start)
# print(eee_start)
plt.barh(year,cse,color="green")
plt.barh(year,it,left=cse,color="red")
plt.barh(year,ece,left=ece_start,color="orange")
plt.barh(year,eee,left=eee_start,color="purple")
plt.show()

# %%
#! Add the legends
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
ece_start = [cse[i] + it[i] for i in range(len(year))]
plt.barh(year,cse,color="red",label="CSE")
plt.barh(year,it,left=cse,color="green",label="IT")
plt.barh(year,ece,left=ece_start,label="ECE")
plt.legend()
plt.show()

# %%
#! Add the legends
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
year = ["2021","2022","2023","2024"]
placement = [150,175,125,100]
cse = [80,95,65,50]
it =  [30,25,20,15]
ece = [12,15,6,18]
eee = [15,20,10,25]
ece_start = [cse[i] +it[i] for i in range(len(year))]
eee_start = [cse[i] + it[i] + ece[i] for i in range(len(year))]   #todo - this type also we can written  
# print(ece_start)
# print(eee_start)
plt.barh(year,cse,color="green",label="CSE")
plt.barh(year,it,left=cse,color="red",label="IT")
plt.barh(year,ece,left=ece_start,color="orange",label="ECE")
plt.barh(year,eee,left=eee_start,color="purple",label="EEE")
plt.legend()
plt.show()
