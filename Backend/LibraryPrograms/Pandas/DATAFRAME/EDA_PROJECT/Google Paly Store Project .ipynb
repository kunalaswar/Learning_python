# %%
#&  ------------------ Google Play Store Project --------------------------

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns",None) # it is only for scroll bar purpose

# %%
#Load the GooglePlaystore CSV file data
df = pd.read_csv("D:\\PYTHON FULL STACK\\LibraryPrograms\\Pandas\\DATAFRAME\\EDA_PROJECT\\googleplaystore1.csv")
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#! find the total numbeer of app in the playstore
# df.count()
# df.size
print("Total Number of App in Google playstore =",df.shape[0])
# Out:
# Total Number of App in Google playstore = 10841

# %%
#!Find the Total number of Columns in Each app of Google play store
print("Total number of Column in Google playstore =",df.shape[1])
# Out:
# Total number of Column in Google playstore = 13

# %%
#! 1) Display top 5 Rows of  DataSets
print("Display top 5 Rows of  DataSets :")
df.head()
# Out:
# Display top 5 Rows of  DataSets :
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
#! 2) Check the Last 3 Rows of the Dataset  
print("Check the Last three rows of the DataSet :")
df.tail(3)
# Out:
# Check the Last three rows of the DataSet :
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# ...

# %%
#! 3) Find Shape of Our DataSet (Number of Rows & Number of Columns)
print("Number of rows and Number of Columns :")  
df.shape
# Out:
# Number of rows and Number of Columns :
# (10841, 13)

# %%
#! 4.) Get Information About Our Dataset Like Total Number Rows, 
#Total Number of Columns, Datatypes of Each Column  And  Memory Requirement
# print(df.info())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#! 5.) Get Overall Statistics About The Dataframe OR
#    Get the Descriptive Statistics about Google Play Store
df.describe() #* Gives only Numerical Columns but Not on Other Columns like str
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#! 5.) Get Overall Statistics About The Dataframe OR
#    Get the Descriptive Statistics about Google Play Store
df.describe(include="all") # Gives Statistical info on  Numerical  and Non-Numerical Columns
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
#!6.) Obtain Total Number of App Titles Contain 'Astrology'
# Here 'Astrology' is the App name or contain in the app name
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df[df["App"] =='Astrology']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df["App"].str.contains("Astrology")  #it internally contain the True
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: App, Length: 10841, dtype: bool

# %%
df[df["App"].str.contains("Astrology") ]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
#!6.) Obtain Total Number of App Titles Contain 'Astrology'
print("Total number of app contain 'Astrology' : ",
      len(df[df["App"].str.contains("Astrology",case=False)])) 
#contains() function is used to check  each string in a Pandas Series contains a specified substring or Not
# Out:
# Total number of app contain 'Astrology' :  3

# %%
#! 7.) Find Average App Rating
# df.columns  #first Access the Series of DataFrame
# print(df["Rating"].mean())
#* OR
#* By Using the agg function 
# print(df["Rating"].agg("mean"))

print("The Average App Rating In Google Play Store=",df['Rating'].mean())
# Out:
# The Average App Rating In Google Play Store= 4.193338315362443

# %%
#Rounding it
print("The Average App Rating In Google Play Store=",round(df['Rating'].mean(),2))
# Out:
# The Average App Rating In Google Play Store= 4.19

# %%
#8.  Find Total Number of Unique Category
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Category"]
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
print("Total number of unique Category = ",df["Category"].nunique())
# Out:
# Total number of unique Category =  34

# %%
# df["Category"].unique().size
#* OR
df["Category"].nunique()
#* OR
len(df["Category"].unique())
# Out:
# 34

# %%
for appname in df["Category"].unique():
    print(appname)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %%
#! 9.) Which Category Getting The Highest Average Rating?
# df.columns
# df.groupby(["Category"])
# for grpname ,grpdata in df.groupby(["Category"]):
#     print("Group Name",grpname)
#     print(grpdata)
df["Category"]
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
df.groupby("Category")["Rating"]

# %%
len(df.groupby("Category")["Rating"].mean())    #34

#*OR
print(df.groupby("Category")["Rating"].mean().head(1))
#*OR
print(df.groupby("Category")["Rating"].mean().nlargest(1))
#*OR
print(df.groupby("Category")["Rating"].mean().max())  #it give only max()
#* OR
print(df.groupby("Category")["Rating"].mean().sort_values(ascending=False)[0])
#* OR
print(df.groupby("Category")["Rating"].mean().sort_values(ascending=True).tail(1))
#* OR
print(df.groupby("Category")["Rating"].mean().sort_values(ascending=False).head(1))
# Out:
# Category
# 1.9    19.0
# Name: Rating, dtype: float64
# Category
# 1.9    19.0
# Name: Rating, dtype: float64
# 19.0
# 19.0
# Category
# 1.9    19.0
# Name: Rating, dtype: float64
# Category
# 1.9    19.0
# Name: Rating, dtype: float64
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19156\181610270.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.groupby("Category")["Rating"].mean().sort_values(ascending=False)[0])

# %%
#! 10.) Find Total Number of App having 5 Star Rating
df.columns
df[df["Rating"]>=5.0]
#* OR
df[df["Rating"]==5]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
#print("Total number of app having highest Rating = ",df[df["Rating"]==5].shape)

print("Total number of app having highest Rating = ",df[df["Rating"]==5].shape[0])

#* OR
print("Total number of app having highest rating = ",len(df[df["Rating"]==5]))
# Out:
# Total number of app having highest Rating =  274
# Total number of app having highest rating =  274

# %%
print("Total number of app having highest rating = ",df[df["Rating"]==5].count().unique()[0])
# Out:
# Total number of app having highest rating =  274

# %%
#! 11.) Find Average Value of Reviews
df.columns
#Here 'reviews' is object type so we can convert into the float type with astype() function
df["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
df["Reviews"].dtype  #object we can not apply the mean to it 
print(df["Reviews"].dtype)
# Out:
# object

# %%
# df["Reviews"].astype(float)     #ValueError: could not convert string to float: '3.0M'

# %%
df[df["Reviews"]=="3.0M"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df["Reviews"].replace("3.0M",3.0*1000000)
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
# It do the permenent changes to the file 
df['Reviews']=df['Reviews'].replace("3.0M",3.0)

# %%
df[df['Reviews']==3.0]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     3.0
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#change the datatype of the  Series Or Column 
df["Reviews"]=df["Reviews"].astype(float)

# %%
# we check it your side
df["Reviews"].dtype
# Out:
# dtype('float64')

# %%
#! 11.) Find Average Value of Reviews
df['Reviews'].mean()
# Out:
# np.float64(444111.9265750392)

# %%
#! 12.) Find Total Number of Free and Paid Apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Type"]=="paid"  #it gives boolean array
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Type, Length: 10841, dtype: bool

# %%
df[df['Type']=="Paid"]
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating  Reviews                Size  Installs  Type   Price  \
# ...

# %%
df[df["Type"]=="Paid"].shape[0]
# Out:
# 800

# %%
# OR
df[df["Type"]=="Paid"].value_counts()
# Out:
# App                                               Category            Rating  Reviews  Size                Installs    Type  Price    Content Rating  Genres                   Last Updated       Current Ver  Android Ver
# Facetune - For Free                               PHOTOGRAPHY         4.4     49553.0  48M                 1,000,000+  Paid  $5.99    Everyone        Photography              July 25, 2018      1.3.1        4.1 and up     3
# AnatomyMapp                                       MEDICAL             4.1     80.0     48M                 5,000+      Paid  $14.99   Everyone        Medical                  November 5, 2013   1.0          3.0 and up     2
# Hospitalist Handbook                              MEDICAL             4.8     12.0     18M                 1,000+      Paid  $19.99   Everyone        Medical                  June 5, 2017       6.0.4        4.1 and up     2
# ...

# %%
df["Type"].value_counts()
s = df["Type"].value_counts()
type(df["Type"].value_counts())
# Out:
# pandas.core.series.Series

# %%
print("---------------------------------------------")
print("Number of Free app =",s["Free"])
print("Number of paid app = ",s["Paid"])
print("Number of Not paid and not Free = ",s["0"])
# Out:
# ---------------------------------------------
# Number of Free app = 10039
# Number of paid app =  800
# Number of Not paid and not Free =  1

# %%
#! 13.)  Which App Has Maximum Reviews?
df.columns
# Out:
# np.float64(78158306.0)

# %%
df["Reviews"].max()
# Out:
# np.float64(78158306.0)

# %%
# here each review value compare with max value
df["Reviews"]==df["Reviews"].max()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
df[df["Reviews"]==df["Reviews"].max()]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres    Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social  August 3, 2018
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
#put the condition Here
df[df["Reviews"]==df["Reviews"].max()]["App"]
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
type(df[df["Reviews"]==df["Reviews"].max()]["App"])
df[df["Reviews"]==df["Reviews"].max()]["App"][2544]
# Out:
# 'Facebook'

# %%
print("The App Has Maximun Reviews = ",df[df["Reviews"]==df["Reviews"].max()]["App"][2544])
# Out:
# The App Has Maximun Reviews =  Facebook

# %%
# df.loc[2544]

# %%
#! 14.) Display Top 5 Apps Having Highest Reviews
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Reviews"].sort_values(ascending=False).head()  #or nlargest(5)
# Out:
# 2544    78158306.0
# 3943    78128208.0
# 381     69119316.0
# 336     69119316.0
# 3904    69109672.0
# Name: Reviews, dtype: float64

# %%
Indices=df["Reviews"].sort_values(ascending=False).head().index

# %%
print(Indices)
# Out:
# Index([2544, 3943, 381, 336, 3904], dtype='int64')

# %%
df.iloc[Indices]
# Out:
#                      App       Category  Rating     Reviews  \
# 2544            Facebook         SOCIAL     4.1  78158306.0
# 3943            Facebook         SOCIAL     4.1  78128208.0
# 381   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672.0
#
#                     Size        Installs  Type Price Content Rating  \
# 2544  Varies with device  1,000,000,000+  Free     0           Teen
# 3943  Varies with device  1,000,000,000+  Free     0           Teen
# 381   Varies with device  1,000,000,000+  Free     0       Everyone
# 336   Varies with device  1,000,000,000+  Free     0       Everyone
# 3904  Varies with device  1,000,000,000+  Free     0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver
# 2544         Social  August 3, 2018  Varies with device  Varies with device
# ...

# %%
df.iloc[Indices]["App"]
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %%
df.iloc[Indices]["App"].value_counts()
# Out:
# App
# WhatsApp Messenger    3
# Facebook              2
# Name: count, dtype: int64

# %%
#! 15.) Find Average Rating of Free and Paid Apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.groupby("Type")["Rating"].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
df.groupby("Type")["Rating"].agg(["mean"])
# Out:
#            mean
# Type
# 0     19.000000
# Free   4.186203
# Paid   4.266615

# %%
print("Average Rating of Free Apps = ",df.groupby("Type")["Rating"].mean()["Free"])
print("Average Rating of paid App = ",df.groupby("Type")["Rating"].mean()["Paid"])
print("Average Rating of 0 App = ",df.groupby("Type")["Rating"].mean()["0"])
# Out:
# Average Rating of Free Apps =  4.186202546163551
# Average Rating of paid App =  4.26661514683153
# Average Rating of 0 App =  19.0

# %%
#! 16.) Display Top  5 Apps Having Maximum Installs
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Installs"]
df["Installs"].dtype
print(df["Installs"].dtype)
# Out:
# object

# %%
# Replace  "," with empty string
df["Installs"].str.replace(",","")
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Installs, Length: 10841, dtype: object

# %%
df["Installs-1"] = df["Installs"].str.replace(",","")

# %%
df["Installs-1"]  #Comma is removed
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Installs-1, Length: 10841, dtype: object

# %%
df["Installs-1"] = df["Installs-1"].str.replace("+","")

# %%
df["Installs-1"] # Replace '+' to ""
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs-1, Length: 10841, dtype: object

# %%
# Convert dtype of df["Installs-1"] into int type
df["Installs-1"] = df["Installs-1"].astype("int")

# %%
df[df["Installs-1"]=="Free"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Installs-1
# 10472       1.0.19  4.0 and up         NaN       Free

# %%
#replace the Installs Free into the 0 
df["Installs-1"]=df["Installs-1"].str.replace("Free","0")

# %%
df[df["Installs-1"]=="0"] # App ---------->  Life Made WI-Fi Touchscreen Photo Frame
# Out:
#                                                 App            Category  \
# 4465   Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 5307                        Ak Parti Yardım Toplama              SOCIAL
# 5486                         AP Series Solution Pro              FAMILY
# 5945                     Ain Arabic Kids Alif Ba ta              FAMILY
# 6692                                  cronometra-br        PRODUCTIVITY
# 7434                                  Pekalongan CJ              SOCIAL
# 8081                                     CX Network            BUSINESS
# 8614                              Sweden Newspapers  NEWS_AND_MAGAZINES
# 8871                         Test Application DT 02      ART_AND_DESIGN
# 9148                      Command & Conquer: Rivals              FAMILY
# 9337                       EG | Explore Folegandros    TRAVEL_AND_LOCAL
# 9719                                   EP Cook Book             MEDICAL
# ...

# %%
#Convert  dtype of df["Installs-1"] into int type
df["Installs-1"] = df["Installs-1"].astype("int")   # put into New column

# %%
# 16) Top  5 Apps Having Maximum Installs
df["Installs-1"].sort_values(ascending=False).head()
# Out:
# 3565    1000000000
# 3896    1000000000
# 381     1000000000
# 335     1000000000
# 3523    1000000000
# Name: Installs-1, dtype: int64

# %%
indices=df["Installs-1"].sort_values(ascending=False).head().index
df.iloc[indices]
# Out:
#                                            App       Category  Rating  \
# 3565                              Google Drive   PRODUCTIVITY     4.4
# 3896                            Subway Surfers           GAME     4.5
# 381                         WhatsApp Messenger  COMMUNICATION     4.4
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 3523                              Google Drive   PRODUCTIVITY     4.4
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# 3565   2731211  Varies with device  1,000,000,000+  Free     0       Everyone
# 3896  27711703                 76M  1,000,000,000+  Free     0   Everyone 10+
# 381   69119316  Varies with device  1,000,000,000+  Free     0       Everyone
# 335   56642847  Varies with device  1,000,000,000+  Free     0       Everyone
# 3523   2731211  Varies with device  1,000,000,000+  Free     0       Everyone
#
# ...

# %%
indices=df["Installs-1"].sort_values(ascending=False).head().index
df.iloc[indices]["App"]
# Out:
# 3565                                Google Drive
# 3896                              Subway Surfers
# 381                           WhatsApp Messenger
# 335     Messenger – Text and Video Chat for Free
# 3523                                Google Drive
# Name: App, dtype: object
